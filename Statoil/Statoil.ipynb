# %% [markdown]
# # Statoil

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle competitions download -c statoil-iceberg-classifier-challenge

# %%
!7z e sample_submission.csv.7z
!7z e test.json.7z
!7z e train.json.7z

# %%
# !ls
# Out:
# kaggle.json  sample_submission.csv     test.json     train.json
# sample_data  sample_submission.csv.7z  test.json.7z  train.json.7z

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pylab
plt.rcParams['figure.figsize'] = 10, 10

# %%
train = pd.read_json('train.json')
test = pd.read_json('test.json')

# %%
train.head()
# Out:
#          id  ... is_iceberg
# 0  dfd5f913  ...          0
# 1  e25388fd  ...          0
# 2  58b2aaa0  ...          1
# 3  4cfc3a18  ...          0
# 4  271f93f4  ...          0
#
# [5 rows x 5 columns]

# %%
test.head()
# Out:
#          id  ...  inc_angle
# 0  5941774d  ...  34.966400
# 1  4023181e  ...  32.615072
# 2  b20200e4  ...  37.505433
# 3  e7f018bb  ...  34.473900
# 4  4371c8c3  ...  43.918874
#
# [5 rows x 4 columns]

# %% [markdown]
# 데이터는 600km 상공에서 촬영된 인공위성에서 촬영 됐습니다.
#
# `id` : 이미지 식별변호(id)
# `band_1`, `band_2` : 5625(75*75) 픽셀 이미지로, 일반적인 이미지 파일(0 ~ 255값의 정수)과 달리 음의 값을 갖는 유리수로 구성 돼 있습니다. 또한, 일반 이미지(RGB 3채널)과 달리 HH, HV로 2채널로 구성돼 있습니다.
# `inc_angle` : 인공위성의 입사각
# `is_control` : 목적 변수로 0은 선박, 1은 빙산

# %%
len(train['band_1'][0]), 75*75
# Out:
# (5625, 5625)

# %%
len(train['inc_angle'])
# Out:
# 1604

# %%
len(train['inc_angle'].unique())
# Out:
# 879

# %%
len(train.loc[train['inc_angle'] == 'na', 'inc_angle'])
# Out:
# 133

# %% [markdown]
# `inc_angle`의 경우 동일한 입사각의 데이터가 존재

# %%
train.loc[train['inc_angle'] == train['inc_angle'].unique()[5]]
# Out:
#             id  ... is_iceberg
# 5     b51d18b5  ...          1
# 192   4b58ca02  ...          1
# 692   63d60bde  ...          1
# 1171  bfd71df1  ...          1
# 1187  38b16888  ...          1
# 1188  3741117d  ...          1
# 1392  5a869fac  ...          1
#
# [7 rows x 5 columns]

# %% [markdown]
# 데이터를 살펴 본 결과
# 동일한 입사각의 데이터는 모두 동일한 `is_iceberg` 값을 갖는다.

# %%
X_band_1 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_1"]])
X_band_2 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in train["band_2"]])
X_train = np.concatenate([X_band_1[:, :, :, np.newaxis], 
                          X_band_2[:, :, :, np.newaxis],
                          ((X_band_1 + X_band_2)/2)[:, :, :, np.newaxis]],
                          axis = -1)

# %%
X_band_1.shape, X_band_2.shape, X_train.shape
# Out:
# ((1604, 75, 75), (1604, 75, 75), (1604, 75, 75, 3))

# %%
import plotly.offline as py
import plotly.tools as tls
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default = 'colab'

def plotmy3d(c, name):
    data = [
        go.Surface(
            z = c
        )
    ]
    layout = go.Layout(
        title = name,
        autosize = False,
        width = 700,
        height = 700,
        margin = dict(
            l = 65,
            r = 50,
            b = 65,
            t = 90
        )
    )
    fig = go.Figure(data = data, layout = layout)
    fig.show()

# %%
plotmy3d(X_band_1[0, :, :], 'iceberg')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="
, -23.154132843017578, -23.379791259765625, -23.611465454101562, -21.171615600585938, -20.49005699157715, -19.26901626586914, -18.717382431030273, -20.16843605041504, -25.727766036987305, -25.433338165283203, -24.346221923828125, -22.93463897705078, -25.14864158630371, -26.34864044189453, -22.306583404541016, -20.824586868286133, -20.996627807617188, -21.351242065429688, -24.605825424194336, -26.348867416381836, -28.12772560119629, -25.148983001708984, -21.534297943115234, -20.49077606201172, -22.935131072998047, -25.14913558959961, -24.606128692626953, -23.380773544311523, -23.38081169128418, -25.1492862701416, -24.34697914123535, -21.35177230834961, -20.825231552124023, -23.61263656616211, -22.935508728027344], [-20.166702270507812, -21.718835830688477, -19.85653305053711, -22.10501480102539, -21.718950271606445, -24.092784881591797, -24.092819213867188, -22.93301773071289, -24.60397720336914, -24.871294021606445, -24.604053497314453, -22.509384155273438, -21.34958267211914, -20.823041915893555, -21.349658966064453, -20.995121002197266, -21.71940040588379, -23.61056137084961, -25.432207107543945, -22.10561752319336, -22.105655670166016, -24.0933837890625, -26.03162384033203, -24.604541778564453, -26.031700134277344, -24.871898651123047, -21.350109100341797, -23.37929916381836, -22.510025024414062, -21.910799026489258, -20.995685577392578, -20.823719024658203, -21.3503360748291, -23.379526138305664, -25.14800262451172, -22.305906295776367, -22.719633102416992, -25.727388381958008, -26.348112106323242, -24.094064712524414, -22.719785690307617, -23.37982 ...

# %%
from matplotlib import pyplot
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Input, Flatten, Activation
from tensorflow.keras.layers import GlobalMaxPooling2D
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.models import Model
from tensorflow.keras import initializers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, Callback, EarlyStopping

# %%
def getModel():
    #Building the model
    gmodel=Sequential()
    #Conv Layer 1
    gmodel.add(Conv2D(64, kernel_size =(3, 3),activation = 'relu', input_shape = (75, 75, 3)))
    gmodel.add(MaxPooling2D(pool_size = (3, 3), strides=(2, 2)))
    gmodel.add(Dropout(0.2))

    #Conv Layer 2
    gmodel.add(Conv2D(128, kernel_size = (3, 3), activation = 'relu' ))
    gmodel.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
    gmodel.add(Dropout(0.2))

    #Conv Layer 3
    gmodel.add(Conv2D(128, kernel_size = (3, 3), activation = 'relu'))
    gmodel.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
    gmodel.add(Dropout(0.2))

    #Conv Layer 4
    gmodel.add(Conv2D(64, kernel_size = (3, 3), activation = 'relu'))
    gmodel.add(MaxPooling2D(pool_size = (2, 2), strides = (2, 2)))
    gmodel.add(Dropout(0.2))

    #Flatten the data for upcoming dense layers
    gmodel.add(Flatten())

    #Dense Layers
    gmodel.add(Dense(512))
    gmodel.add(Activation('relu'))
    gmodel.add(Dropout(0.2))

    #Dense Layer 2
    gmodel.add(Dense(256))
    gmodel.add(Activation('relu'))
    gmodel.add(Dropout(0.2))

    #Sigmoid Layer
    gmodel.add(Dense(1))
    gmodel.add(Activation('sigmoid'))

    mypotim=Adam(lr = 0.001, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-08, decay = 0.0)
    gmodel.compile(loss = 'binary_crossentropy',
                  optimizer = mypotim,
                  metrics = ['accuracy'])
    gmodel.summary()
    return gmodel


def get_callbacks(filepath, patience = 2):
    es = EarlyStopping('val_loss', patience = patience, mode = "min")
    msave = ModelCheckpoint(filepath, save_best_only = True)
    return [es, msave]
    
file_path = ".model_weights.hdf5"
callbacks = get_callbacks(filepath=file_path, patience = 5)

# %%
target_train = train['is_iceberg']
X_train_cv, X_valid, y_train_cv, y_valid = train_test_split(X_train, target_train, random_state = 1, train_size = 0.75)

# %%
import os
gmodel = getModel()
gmodel.fit(X_train_cv, y_train_cv,
          batch_size = 24,
          epochs = 50,
          verbose = 1,
          validation_data = (X_valid, y_valid),
          callbacks = callbacks)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 73, 73, 64)        1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 36, 36, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 7, 7, 128)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 5, 5, 64)          73792
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 64)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 2, 2, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 512)               131584
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_1 (Activation)    (None, 256)               0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 560,193
# Trainable params: 560,193
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.9761 - accuracy: 0.5337 - val_loss: 0.5798 - val_accuracy: 0.6459
# Epoch 2/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5649 - accuracy: 0.6592 - val_loss: 0.6442 - val_accuracy: 0.6983
# Epoch 3/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5510 - accuracy: 0.6833 - val_loss: 0.5312 - val_accuracy: 0.7581
# Epoch 4/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5188 - accuracy: 0.7116 - val_loss: 0.5034 - val_accuracy: 0.7506
# Epoch 5/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5150 - accuracy: 0.7082 - val_loss: 0.5160 - val_accuracy: 0.7406
# Epoch 6/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.5078 - accuracy: 0.7240 - val_loss: 0.4996 - val_accuracy: 0.7706
# Epoch 7/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4845 - accuracy: 0.7631 - val_loss: 0.4593 - val_accuracy: 0.7681
# Epoch 8/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4412 - accuracy: 0.7938 - val_loss: 0.4521 - val_accuracy: 0.7830
# Epoch 9/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4580 - accuracy: 0.7805 - val_loss: 0.4984 - val_accuracy: 0.7481
# Epoch 10/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4800 - accuracy: 0.7739 - val_loss: 0.4367 - val_accuracy: 0.7980
# Epoch 11/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4378 - accuracy: 0.7938 - val_loss: 0.4617 - val_accuracy: 0.7681
# Epoch 12/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4290 - accuracy: 0.7997 - val_loss: 0.4365 - val_accuracy: 0.7955
# Epoch 13/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4383 - accuracy: 0.7980 - val_loss: 0.4103 - val_accuracy: 0.8030
# Epoch 14/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4320 - accuracy: 0.8155 - val_loss: 0.4219 - val_accuracy: 0.7980
# Epoch 15/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4293 - accuracy: 0.7947 - val_loss: 0.4255 - val_accuracy: 0.8080
# Epoch 16/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4165 - accuracy: 0.8063 - val_loss: 0.4300 - val_accuracy: 0.8005
# Epoch 17/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4507 - accuracy: 0.7706 - val_loss: 0.4029 - val_accuracy: 0.8030
# Epoch 18/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.4128 - accuracy: 0.8005 - val_loss: 0.3800 - val_accuracy: 0.8329
# Epoch 19/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4298 - accuracy: 0.7764 - val_loss: 0.4454 - val_accuracy: 0.7930
# Epoch 20/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.4270 - accuracy: 0.8121 - val_loss: 0.3828 - val_accuracy: 0.8180
# Epoch 21/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3985 - accuracy: 0.8188 - val_loss: 0.3951 - val_accuracy: 0.8204
# Epoch 22/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3899 - accuracy: 0.8271 - val_loss: 0.3718 - val_accuracy: 0.8628
# Epoch 23/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3829 - accuracy: 0.8288 - val_loss: 0.3835 - val_accuracy: 0.8329
# Epoch 24/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3815 - accuracy: 0.8221 - val_loss: 0.3944 - val_accuracy: 0.8204
# Epoch 25/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3778 - accuracy: 0.8238 - val_loss: 0.3872 - val_accuracy: 0.8055
# Epoch 26/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3614 - accuracy: 0.8404 - val_loss: 0.3603 - val_accuracy: 0.8603
# Epoch 27/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3640 - accuracy: 0.8304 - val_loss: 0.3433 - val_accuracy: 0.8603
# Epoch 28/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3420 - accuracy: 0.8429 - val_loss: 0.3972 - val_accuracy: 0.8254
# Epoch 29/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3600 - accuracy: 0.8313 - val_loss: 0.3894 - val_accuracy: 0.8254
# Epoch 30/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3304 - accuracy: 0.8404 - val_loss: 0.3365 - val_accuracy: 0.8504
# Epoch 31/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3429 - accuracy: 0.8329 - val_loss: 0.3986 - val_accuracy: 0.8354
# Epoch 32/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3328 - accuracy: 0.8454 - val_loss: 0.3582 - val_accuracy: 0.8603
# Epoch 33/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3048 - accuracy: 0.8562 - val_loss: 0.3949 - val_accuracy: 0.8254
# Epoch 34/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3267 - accuracy: 0.8470 - val_loss: 0.3187 - val_accuracy: 0.8678
# Epoch 35/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3260 - accuracy: 0.8620 - val_loss: 0.2833 - val_accuracy: 0.8853
# Epoch 36/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2962 - accuracy: 0.8579 - val_loss: 0.3608 - val_accuracy: 0.8753
# Epoch 37/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.3985 - accuracy: 0.8130 - val_loss: 0.2953 - val_accuracy: 0.8753
# Epoch 38/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2842 - accuracy: 0.8803 - val_loss: 0.6293 - val_accuracy: 0.7980
# Epoch 39/50
# 51/51 [==============================] - 1s 12ms/step - loss: 0.3162 - accuracy: 0.8554 - val_loss: 0.2796 - val_accuracy: 0.8928
# Epoch 40/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2779 - accuracy: 0.8678 - val_loss: 0.3227 - val_accuracy: 0.8778
# Epoch 41/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2876 - accuracy: 0.8662 - val_loss: 0.2921 - val_accuracy: 0.8928
# Epoch 42/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2743 - accuracy: 0.8770 - val_loss: 0.3279 - val_accuracy: 0.8678
# Epoch 43/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2540 - accuracy: 0.8861 - val_loss: 0.3255 - val_accuracy: 0.8828
# Epoch 44/50
# 51/51 [==============================] - 1s 11ms/step - loss: 0.2653 - accuracy: 0.8786 - val_loss: 0.3046 - val_accuracy: 0.8878

# %%
gmodel.load_weights(filepath = file_path)
score = gmodel.evaluate(X_valid, y_valid, verbose = 1)
print('Test loss : ', score[0])
print('Test accuracy : ', score[1])
# Out:
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2829 - accuracy: 0.8928
# Test loss :  0.2828901708126068
# Test accuracy :  0.8927680850028992

# %%
X_band_test_1 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test['band_1']])
X_band_test_2 = np.array([np.array(band).astype(np.float32).reshape(75, 75) for band in test['band_2']])
X_test = np.concatenate([X_band_test_1[:, :, :, np.newaxis],
                         X_band_test_2[:, :, :, np.newaxis],
                         ((X_band_test_1 + X_band_test_2)/2)[:, :, :, np.newaxis]], axis = -1)
predicted_test = gmodel.predict_proba(X_test)

# %%
predicted_test
# Out:
# array([[4.3599628e-02],
#        [6.5314847e-01],
#        [9.3002375e-03],
#        ...,
#        [8.3133712e-02],
#        [9.9125963e-01],
#        [8.9207806e-06]], dtype=float32)

# %% [markdown]
# ## Reference
# - [Keras Model for Beginners (0.210 on LB)+EDA+R&D](https://www.kaggle.com/devm2024/keras-model-for-beginners-0-210-on-lb-eda-r-d)
